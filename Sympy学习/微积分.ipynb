# %%
from sympy import *

# %%
x = Symbol('x')
y = Symbol('y')
f = x*log(x)
integrate(f,x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-097997355336> in <module>
# ----> 1 x = Symbol('x')
#       2 y = Symbol('y')
#       3 f = x*log(x)
#       4 integrate(f,x)
#
# NameError: name 'Symbol' is not defined

# %%
integrate(f,(y,0,1))
# Out:
# -x/(2*x**2 + 2) + 1/(2*x)

# %%
n = Symbol('n')
f2 = sqrt(n)*x/(1+n*x**2)*sin(n*x)*cos(2*n*x)
integrate(f2,(x,0,1))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-69361bb8587e> in <module>
#       1 n = Symbol('n')
#       2 f2 = sqrt(n)*x/(1+n*x**2)*sin(n*x)*cos(2*n*x)
# ----> 3 integrate(f2,(x,0,1))
#
# ~\AppData\Roaming\Python\Python37\site-packages\sympy\integrals\integrals.py in integrate(*args, **kwargs)
#    1520
#    1521     if isinstance(integral, Integral):
# -> 1522         return integral.doit(**doit_flags)
#    1523     else:
#    1524         new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#
# ~\AppData\Roaming\Python\Python37\site-packages\sympy\integrals\integrals.py in doit(self, **hints)
#     462         if reps:
#     463             undo = dict([(v, k) for k, v in reps.items()])
# --> 464             did = self.xreplace(reps).doit(**hints)
#     465             if type(did) is tuple:  # when separate=True
# ...
